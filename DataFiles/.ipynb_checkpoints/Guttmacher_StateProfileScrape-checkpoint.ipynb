# %% [markdown]
# ## Webscrape More Updated Data From Guttmacher's State Profiles

# %%
# SCRAPING THE CONTENTS FROM https://states.guttmacher.org/policies/

# DEPENDENCIES
import requests
import json
import pandas as pd
import numpy as np

# %%
url = "https://states.guttmacher.org/policies/guttmacher.json"

# %%
response = requests.get(url).json()
# print(json.dumps(response, indent=4, sort_keys=True))

# %% [markdown]
# ### Pulling the data from Guttmacher's JSON source

# %%
all_abortion_df = pd.json_normalize(response)

# %%
all_abortion_df.head()
print(type(all_abortion_df))
all_abortion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 23 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   state                                                       51 non-null     object
#  1   state_slug                                                  51 non-null     object
#  2   environment_type                                            51 non-null     object
#  3   policies_currently_in_effect                                51 non-null     object
#  4   wora_in_state_15_49                                         51 non-null     object
#  5   wora_in_state_15_49_breakdown                               51 non-null     object
#  6   residents_in_state_born_outside_us                          51 non-null     int64
#  7   income_level_below_fpl                                      51 non-null     int64
#  8   insurance_coverage_breakdown                                51 non-null     object
#  9   wora_age_breakdown                                          51 non-null     object
#  10  abortions_obtained_in_2017                                  51 non-null     object
#  11  abortions_per_1000_women_aged_15_44_in_2017                 51 non-null     float64
#  12  clinics_provided_abortion_in_2017                           51 non-null     int64
#  13  counties_without_abortion_provider_in_2017                  51 non-null     int64
#  14  residents_in_counties_without_an_abortion_provider_in_2017  51 non-null     int64
#  15  aowdd_15_49_6_weeks                                         51 non-null     object
#  16  aowdd_15_49_12_weeks                                        51 non-null     object
#  17  aowdd_15_49_14_weeks                                        51 non-null     object
#  18  aowdd_15_49_after_14_weeks                                  51 non-null     object
#  19  aowdd_15_49_20_weeks                                        51 non-null     object
#  20  aowdd_15_49_22_weeks                                        51 non-null     object
#  21  aowdd_15_49_24_weeks                                        51 non-null     object
#  22  aowdd_15_49_after_24_weeks                                  51 non-null     object
# dtypes: float64(1), int64(5), object(17)
# memory usage: 9.3+ KB

# %%
abortion_2020_data = all_abortion_df[["state", 
                                      "state_slug", 
                                      "policies_currently_in_effect",
                                      "environment_type", 
                                      "residents_in_state_born_outside_us", 
                                      "income_level_below_fpl", 
                                      "abortions_obtained_in_2017",
                                      "abortions_per_1000_women_aged_15_44_in_2017",
                                      "clinics_provided_abortion_in_2017", 
                                      "counties_without_abortion_provider_in_2017",
                                      "residents_in_counties_without_an_abortion_provider_in_2017" ]]
# abortion_2020_data.head()

# %%
# # Adjusting columns to display percentages as floats instead of whole numbers
# abortion_2020_data.loc[:,"residents_in_state_born_outside_us"] *= 0.01
# abortion_2020_data.loc[:,"income_level_below_fpl"] *= 0.01
# abortion_2020_data.loc[:,"residents_in_counties_without_an_abortion_provider_in_2017"] *= 0.01

# %%
# Changing number of abortions obtained from object to integer

abortion_2020_data.loc[:,"abortions_obtained_in_2017"] = abortion_2020_data["abortions_obtained_in_2017"].astype(str)

comma = ","
abortion_2020_data.loc[:,"abortions_obtained_in_2017"] = [each.replace(comma, "") for each in abortion_2020_data["abortions_obtained_in_2017"]]
abortion_2020_data.loc[:,"abortions_obtained_in_2017"] = abortion_2020_data["abortions_obtained_in_2017"].astype(int)
# Out:
# C:\Users\US11338\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
# abortion_2020_data.head()

# %% [markdown]
# ### Cleaning Driving Distance Data

# %%
# Field "aowdd_15_49_after_14_weeks" dropped for lack of data
driving_distance = all_abortion_df[["state",
                                    "aowdd_15_49_6_weeks", 
                                    "aowdd_15_49_12_weeks",
                                    "aowdd_15_49_14_weeks",
                                    "aowdd_15_49_20_weeks",
                                    "aowdd_15_49_22_weeks", 
                                    "aowdd_15_49_24_weeks",
                                    "aowdd_15_49_after_24_weeks"]]
# driving_distance.head()

# %%
# Driving distance is shown as a string in the dataset, e.g. ""Average one-way driving distance for women aged 15-49 in Arizona to the nearest clinic that performs abortions up to 20 weeks = 11 miles"
# New columns are created below to pull the number of average miles from each field
driving_distance.loc[:,"week_6"] = driving_distance.aowdd_15_49_6_weeks.str.split("\s+").str[-2]
driving_distance.loc[:,"week_12"] = driving_distance.aowdd_15_49_12_weeks.str.split("\s+").str[-2]
driving_distance.loc[:,"week_14"] = driving_distance.aowdd_15_49_14_weeks.str.split("\s+").str[-2]
driving_distance.loc[:,"week_20"] = driving_distance.aowdd_15_49_20_weeks.str.split("\s+").str[-2]
driving_distance.loc[:,"week_22"] = driving_distance.aowdd_15_49_22_weeks.str.split("\s+").str[-2]
driving_distance.loc[:,"week_24"] = driving_distance.aowdd_15_49_24_weeks.str.split("\s+").str[-2]
driving_distance.loc[:,"week_24_plus"] = driving_distance.aowdd_15_49_after_24_weeks.str.split("\s+").str[-2]

# driving_distance.head()
# Out:
# C:\Users\US11338\Anaconda3\lib\site-packages\pandas\core\indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
# driving_distance.info()

# %%
# Shows the average one-way driving distance for a woman to obtain an abortion at the given week threshold
driving_distance = driving_distance[["state", "week_6", "week_12", "week_14", "week_20", "week_22", "week_24", "week_24_plus"]]
driving_distance["week_24_plus"] = driving_distance["week_24_plus"].str.replace("in", "0")
# driving_distance.info()

# %%
driving_distance2 = driving_distance.astype({"week_6": float, "week_12": float, "week_14": float, "week_20": float,"week_22": float, "week_24": float, "week_24_plus": float})
# driving_distance2

# %%
driving_distance3 = driving_distance2.melt(id_vars=["state"], var_name="week_threshold", value_name="avg_oneway_miles").sort_values(["state"])
# driving_distance3.head()

# %% [markdown]
# ### Cleaning Race/Ethnicity Data

# %%
wora_ethnicities = all_abortion_df[["state","wora_in_state_15_49_breakdown"]]
# wora_ethnicities.head()

# %%
wora_ethnicities2 = wora_ethnicities.wora_in_state_15_49_breakdown.str.split(" ", expand = True)
wora_ethnicities2 = wora_ethnicities2[[1,4,7,10,13]]
# wora_ethnicities2.head()

# %%
wora_ethnicities3 = pd.merge(wora_ethnicities, wora_ethnicities2, left_index=True, right_index=True)
wora_ethnicities3.rename(columns={"wora_in_state_15_49_breakdown":"original_string", 1:"Hispanic", 4:"White", 7:"Black", 10:"Asian", 13:"Other"}, inplace=True)
# wora_ethnicities3.info()

# %%
char = "%"
wora_ethnicities3["Hispanic"] = ([each.replace(char, "") for each in wora_ethnicities3["Hispanic"]])
wora_ethnicities3["White"] = ([each.replace(char, "") for each in wora_ethnicities3["White"]])
wora_ethnicities3["Black"] = ([each.replace(char, "") for each in wora_ethnicities3["Black"]])
wora_ethnicities3["Asian"] = ([each.replace(char, "") for each in wora_ethnicities3["Asian"]])
wora_ethnicities3["Other"] = ([each.replace(char, "") for each in wora_ethnicities3["Other"]])
# wora_ethnicities3.info()

# %%
wora_ethnicities4 = wora_ethnicities3.astype({"Hispanic": float, "White": float, "Black": float, "Asian": float,"Other": float})

# %%
wora_ethnicities4 = wora_ethnicities4[["Hispanic", "White", "Black", "Asian", "Other"]]

# %%
wora_ethnicities5 = pd.merge(wora_ethnicities3, wora_ethnicities4, left_index = True, right_index = True)
wora_ethnicities5 = wora_ethnicities5[["state", "Hispanic_y", "White_y", "Black_y","Asian_y", "Other_y"]]
wora_ethnicities5 = wora_ethnicities5.rename(columns={"Hispanic_y":"Hispanic", "White_y":"White", "Black_y":"Black", "Asian_y":"Asian", "Other_y":"Other"})
# wora_ethnicities5.info()

# %%
wora_ethnicities6 = wora_ethnicities5.melt(id_vars=["state"], var_name="Race/Ethnicity", value_name="Portion of WORA").sort_values(["state"])
wora_ethnicities6 = pd.DataFrame(wora_ethnicities6)
# wora_ethnicities6.head()

# %% [markdown]
# ### Cleaning Age Breakdown

# %%
ages = all_abortion_df[["state","wora_age_breakdown"]]
# print(ages)

# %%
ages_2 = ages.wora_age_breakdown.str.split(" ", expand = True)
ages_2 = ages_2[[1,5,9,13,17, 21]]
# ages_2.head()

# %%
ages_3 = pd.merge(ages, ages_2, left_index=True, right_index=True)
ages_3.rename(columns={"wora_age_breakdown":"original_string", 1:"15-17 Years", 5:"18-19 Years", 9:"20-24 Years", 13:"25-29 Years", 17:"30-39 Years", 21:"40-49 Years"}, inplace=True)
# ages_3.head()

# %%
char = "%"
ages_3["15-17 Years"] = ([each.replace(char, "") for each in ages_3["15-17 Years"]])
ages_3["18-19 Years"] = ([each.replace(char, "") for each in ages_3["18-19 Years"]])
ages_3["20-24 Years"] = ([each.replace(char, "") for each in ages_3["20-24 Years"]])
ages_3["25-29 Years"] = ([each.replace(char, "") for each in ages_3["25-29 Years"]])
ages_3["30-39 Years"] = ([each.replace(char, "") for each in ages_3["30-39 Years"]])
ages_3["40-49 Years"] = ([each.replace(char, "") for each in ages_3["40-49 Years"]])

# %%
ages_4 = ages_3.astype({"15-17 Years": float, 
                        "18-19 Years": float,
                        "20-24 Years": float,  
                        "25-29 Years": float, 
                        "30-39 Years": float,
                        "40-49 Years": float})

# %%
ages_4 = ages_4[["15-17 Years", "18-19 Years","20-24 Years",  "25-29 Years","30-39 Years","40-49 Years"]]

# %%
ages_5 = pd.merge(ages, ages_4, left_index = True, right_index = True)
ages_5 = ages_5[["state", "15-17 Years", "18-19 Years", "20-24 Years", "25-29 Years", "30-39 Years", "40-49 Years"]]

# %%
ages_6 = ages_5.melt(id_vars=["state"], var_name="Age Group", value_name="Portion of WORA").sort_values(["state"])
# ages_6.head(15)
ages_6 = pd.DataFrame(ages_6)
ages_6.head()
# Out:
#        state    Age Group  Portion of WORA
# 0    Alabama  15-17 Years              8.0
# 102  Alabama  20-24 Years             14.0
# 153  Alabama  25-29 Years             15.0
# 204  Alabama  30-39 Years             29.0
# 255  Alabama  40-49 Years             28.0

# %% [markdown]
# ### Cleaning the number of women of reproductive age (WORA) in the state from object to integer

# %%
wora_in_state = all_abortion_df[["state", "wora_in_state_15_49"]]
# wora_in_state.head(20)

# %%
# Changing the number of women of reproductive age from object to integer

# split "million" from the cell by splitting on space
appx_wora = wora_in_state.wora_in_state_15_49.str.split(expand = True)

# remove the non-digits from the first column in order to change the values to an integer
point = "."
appx_wora[0] = ([each.replace(comma, "") for each in appx_wora[0]])
appx_wora[0] = ([each.replace(point, "") for each in appx_wora[0]])
appx_wora[0] = appx_wora[0].astype(int)

# multiply the values that had been labeled "million" by 100,000 (removing the decimal earlier changed the scale of the number from a million to 100,000)
appx_wora.loc[appx_wora[1]=="million", "number"] = appx_wora[0]*100000
appx_wora["final_number"] = appx_wora["number"].fillna(appx_wora[0])

# merge this cleaned data back to the wora_in_state dataframe
wora_in_state_2 = pd.merge(wora_in_state, appx_wora["final_number"], left_index = True, right_index=True)

# %%
# Combine dataframes wora_in_state_2, wora_ethnicities5, ages_5, driving_distance2 onto abortion_2020_data

abortion_data_1 = pd.merge(abortion_2020_data, wora_in_state_2, left_index=True, right_index=True)
abortion_data_2 = pd.merge(abortion_data_1,wora_ethnicities5, left_index=True, right_index=True)
abortion_data_3 = pd.merge(abortion_data_2,ages_5, left_index=True, right_index=True)
abortion_data = pd.merge(abortion_data_3,driving_distance2, left_index=True, right_index=True)

abortion_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 35 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   state_x                                                     51 non-null     object
#  1   state_slug                                                  51 non-null     object
#  2   policies_currently_in_effect                                51 non-null     object
#  3   environment_type                                            51 non-null     object
#  4   residents_in_state_born_outside_us                          51 non-null     int64
#  5   income_level_below_fpl                                      51 non-null     int64
#  6   abortions_obtained_in_2017                                  51 non-null     int32
#  7   abortions_per_1000_women_aged_15_44_in_2017                 51 non-null     float64
#  8   clinics_provided_abortion_in_2017                           51 non-null     int64
#  9   counties_without_abortion_provider_in_2017                  51 non-null     int64
#  10  residents_in_counties_without_an_abortion_provider_in_2017  51 non-null     int64
#  11  state_y                                                     51 non-null     object
#  12  wora_in_state_15_49                                         51 non-null     object
#  13  final_number                                                51 non-null     float64
#  14  state_x                                                     51 non-null     object
#  15  Hispanic                                                    51 non-null     float64
#  16  White                                                       51 non-null     float64
#  17  Black                                                       51 non-null     float64
#  18  Asian                                                       51 non-null     float64
#  19  Other                                                       51 non-null     float64
#  20  state_y                                                     51 non-null     object
#  21  15-17 Years                                                 51 non-null     float64
#  22  18-19 Years                                                 51 non-null     float64
#  23  20-24 Years                                                 51 non-null     float64
#  24  25-29 Years                                                 51 non-null     float64
#  25  30-39 Years                                                 51 non-null     float64
#  26  40-49 Years                                                 51 non-null     float64
#  27  state                                                       51 non-null     object
#  28  week_6                                                      4 non-null      float64
#  29  week_12                                                     32 non-null     float64
#  30  week_14                                                     24 non-null     float64
#  31  week_20                                                     48 non-null     float64
#  32  week_22                                                     35 non-null     float64
#  33  week_24                                                     38 non-null     float64
#  34  week_24_plus                                                50 non-null     float64
# dtypes: float64(20), int32(1), int64(5), object(9)
# memory usage: 13.9+ KB
# C:\Users\US11338\AppData\Local\Temp/ipykernel_14112/632021400.py:5: FutureWarning: Passing 'suffixes' which cause duplicate columns {'state_x'} in the result is deprecated and will raise a MergeError in a future version.
#   abortion_data_3 = pd.merge(abortion_data_2,ages_5, left_index=True, right_index=True)

# %%
# NOTE: the field names from the webscrape were not updated to reflect the year of data they actually display
# Confirmed from Guttmacher data available for download here: 
    # https://www.poynter.org/reporting-editing/2022/the-us-saw-930160-abortions-in-2020-reversing-a-30-year-decline/
# It includes both 2017 and 2020 values for the number of abortions and rate per 1000 women
# Unless stated otherwise, assume data is from 2017

abortion_data = abortion_data.rename(columns={"state": "State", 
                                              "state_slug":"State URL Slug", 
                                              "environment_type":"Restrictive Category",
                                              "policies_currently_in_effect": "Current Policies",
                                              "residents_in_state_born_outside_us":"% WORA Residents Non-US", 
                                              "income_level_below_fpl": "% WORA Below FPL",
                                              "abortions_obtained_in_2017":"Abortions Obtained in 2020", 
                                              "abortions_per_1000_women_aged_15_44_in_2017": "Abortions per 1,000 WORA in 2020", 
                                              "clinics_provided_abortion_in_2017": "Abortion Clinics", 
                                              "counties_without_abortion_provider_in_2017":"Counties w/o Abortion Providers", 
                                              "residents_in_counties_without_an_abortion_provider_in_2017":"% WORA w/o County Abortion Provider", 
                                              "final_number": "Appx. Number of WORA", 
                                              "Hispanic":"% WORA: Hispanic", 
                                              "Black":"% WORA: Black", 
                                              "White":"% WORA: White", 
                                              "Asian":"% WORA: Asian", \
                                              "Other":"% WORA: Other", 
                                              "15-17 Years": "% WORA: 15-17 Years",
                                              "18-19 Years": "% WORA: 18-19 Years", 
                                              "20-24 Years": "% WORA: 20-24 Years", 
                                              "25-29 Years": "% WORA: 25-29 Years",
                                              "30-39 Years": "% WORA: 30-39 Years",
                                              "40-49 Years": "% WORA: 40-49 Years", 
                                              "week_6":"Avg. Distance (mi): 6 Weeks", 
                                              "week_12":"Avg. Distance (mi): 12 Weeks", 
                                              "week_14":"Avg. Distance (mi): 14 Weeks", 
                                              "week_20":"Avg. Distance (mi): 20 Weeks", 
                                              "week_22":"Avg. Distance (mi): 22 Weeks", 
                                              "week_24":"Avg. Distance (mi): 24 Weeks", 
                                              "week_24_plus":"Avg. Distance (mi): 24+ Weeks"})

# %%
abortion_data2 = abortion_data[["State","State URL Slug","Restrictive Category","Current Policies","Abortions Obtained in 2020", 
                               "Abortions per 1,000 WORA in 2020","Appx. Number of WORA", "Abortion Clinics","Counties w/o Abortion Providers",
                               "% WORA w/o County Abortion Provider", "% WORA Residents Non-US","% WORA Below FPL",
                               "% WORA: Hispanic","% WORA: Black","% WORA: White","% WORA: Asian","% WORA: Other", 
                               "% WORA: 15-17 Years", "% WORA: 18-19 Years", "% WORA: 20-24 Years", 
                               "% WORA: 25-29 Years","% WORA: 30-39 Years", "% WORA: 40-49 Years",
                               "Avg. Distance (mi): 6 Weeks", "Avg. Distance (mi): 12 Weeks", "Avg. Distance (mi): 14 Weeks", 
                               "Avg. Distance (mi): 20 Weeks", "Avg. Distance (mi): 22 Weeks","Avg. Distance (mi): 24 Weeks","Avg. Distance (mi): 24+ Weeks"]]

# %%
abortion_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                51 non-null     object
#  1   State URL Slug                       51 non-null     object
#  2   Restrictive Category                 51 non-null     object
#  3   Current Policies                     51 non-null     object
#  4   Abortions Obtained in 2020           51 non-null     int32
#  5   Abortions per 1,000 WORA in 2020     51 non-null     float64
#  6   Appx. Number of WORA                 51 non-null     float64
#  7   Abortion Clinics                     51 non-null     int64
#  8   Counties w/o Abortion Providers      51 non-null     int64
#  9   % WORA w/o County Abortion Provider  51 non-null     int64
#  10  % WORA Residents Non-US              51 non-null     int64
#  11  % WORA Below FPL                     51 non-null     int64
#  12  % WORA: Hispanic                     51 non-null     float64
#  13  % WORA: Black                        51 non-null     float64
#  14  % WORA: White                        51 non-null     float64
#  15  % WORA: Asian                        51 non-null     float64
#  16  % WORA: Other                        51 non-null     float64
#  17  % WORA: 15-17 Years                  51 non-null     float64
#  18  % WORA: 18-19 Years                  51 non-null     float64
#  19  % WORA: 20-24 Years                  51 non-null     float64
#  20  % WORA: 25-29 Years                  51 non-null     float64
#  21  % WORA: 30-39 Years                  51 non-null     float64
#  22  % WORA: 40-49 Years                  51 non-null     float64
#  23  Avg. Distance (mi): 6 Weeks          4 non-null      float64
#  24  Avg. Distance (mi): 12 Weeks         32 non-null     float64
#  25  Avg. Distance (mi): 14 Weeks         24 non-null     float64
#  26  Avg. Distance (mi): 20 Weeks         48 non-null     float64
#  27  Avg. Distance (mi): 22 Weeks         35 non-null     float64
#  28  Avg. Distance (mi): 24 Weeks         38 non-null     float64
#  29  Avg. Distance (mi): 24+ Weeks        50 non-null     float64
# dtypes: float64(20), int32(1), int64(5), object(4)
# memory usage: 11.9+ KB

# %%
abortion_data_cleaned = abortion_data2
abortion_data_cleaned
# Out:
#              State  State URL Slug           Restrictive Category  \
# 0          Alabama         alabama               Most Restrictive
# 1           Alaska          alaska                     Protective
# 2          Arizona         arizona                    Restrictive
# 3         Arkansas        arkansas               Most Restrictive
# 4       California      california                     Protective
# 5         Colorado        colorado                     Protective
# 6      Connecticut     connecticut  Some Restrictions/Protections
# 7               DC              dc  Some Restrictions/Protections
# 8         Delaware        delaware  Some Restrictions/Protections
# 9          Florida         florida                    Restrictive
# 10         Georgia         georgia                    Restrictive
# 11          Hawaii          hawaii  Some Restrictions/Protections
# 12           Idaho           idaho                    Restrictive
# 13        Illinois        illinois                     Protective
# 14         Indiana         indiana                    Restrictive
# 15            Iowa            iowa                    Restrictive
# 16          Kansas          kansas                    Restrictive
# 17        Kentucky        kentucky                    Restrictive
# 18       Louisiana       louisiana                    Restrictive
# 19           Maine           maine                     Protective
# 20        Maryland        maryland  Some Restrictions/Protections
# 21   Massachusetts   massachusetts  Some Restrictions/Protections
# 22        Michigan        michigan  Some Restrictions/Protections
# 23       Minnesota       minnesota  Some Restrictions/Protections
# 24     Mississippi     mississippi                    Restrictive
# 25        Missouri        missouri               Most Restrictive
# 26         Montana         montana  Some Restrictions/Protections
# 27        Nebraska        nebraska                    Restrictive
# 28          Nevada          nevada  Some Restrictions/Protections
# 29   New Hampshire   new-hampshire  Some Restrictions/Protections
# 30      New Jersey      new-jersey                     Protective
# 31      New Mexico      new-mexico                     Protective
# 32        New York        new-york                     Protective
# 33  North Carolina  north-carolina  Some Restrictions/Protections
# 34    North Dakota    north-dakota                    Restrictive
# 35            Ohio            ohio               Very Restrictive
# 36        Oklahoma        oklahoma               Most Restrictive
# 37          Oregon          oregon                Most Protective
# 38    Pennsylvania    pennsylvania                    Restrictive
# 39    Rhode Island    rhode-island  Some Restrictions/Protections
# 40  South Carolina  south-carolina               Very Restrictive
# 41    South Dakota    south-dakota               Most Restrictive
# 42       Tennessee       tennessee               Very Restrictive
# 43           Texas           texas               Very Restrictive
# 44            Utah            utah                    Restrictive
# 45         Vermont         vermont                     Protective
# 46        Virginia        virginia  Some Restrictions/Protections
# 47      Washington      washington                     Protective
# 48   West Virginia   west-virginia                    Restrictive
# 49       Wisconsin       wisconsin                    Restrictive
# 50         Wyoming         wyoming  Some Restrictions/Protections
#
#                                      Current Policies  \
# 0   Abortion is completely banned with very limite...
# 1   Only physicians can provide abortions and not ...
# 2   Pre-Roe abortion ban is still in place and can...
# 3   Abortion is completely banned with very limite...
# 4   Abortion is banned at fetal viability, general...
# 5   Abortion is not restricted based on gestationa...
# 6   Abortion is banned at fetal viability, general...
# 7   State Medicaid coverage of abortion care is ba...
# 8   Abortion is banned at fetal viability, general...
# 9   Abortion is banned at 24 weeks and later  | Pa...
# 10  Abortion is banned at 22 weeks and later | Pat...
# 11  Abortion is banned at fetal viability, general...
# 12  “Trigger” ban on abortion is designed to take ...
# 13  Abortion is banned at fetal viability, general...
# 14  Abortion is banned at 22 weeks and later |Pati...
# 15  Abortion is banned at 22 weeks and later | Pat...
# 16  Abortion is banned at 22 weeks and later |Pati...
# 17  “Trigger” ban on abortion is designed to take ...
# 18  “Trigger” ban on abortion is designed to take ...
# 19  Abortion is banned at fetal viability, general...
# 20  Abortion is banned at fetal viability, general...
# 21  Abortion is banned at 24 weeks and later |Pare...
# 22  Pre-Roe abortion ban is still in place and can...
# 23  Abortion is banned at fetal viability, general...
# 24  Pre-Roe abortion ban is still in place and can...
# 25  Abortion is completely banned with very limite...
# 26  Abortion is banned at fetal viability, general...
# 27  Abortion is banned at 22 weeks and later |Pati...
# 28  Abortion is banned at 24 weeks and later |Stat...
# 29  Abortion is banned at 24 weeks and later |Stat...
# 30  Abortion is not restricted based on gestationa...
# 31  Abortion is not restricted based on gestationa...
# 32  Abortion is banned at fetal viability, general...
# 33  Abortion is banned at fetal viability, general...
# 34  “Trigger” ban on abortion is designed to take ...
# 35  Abortion is banned at 6 weeks and later | Pati...
# 36  Abortion is completely banned with very limite...
# 37  Abortion is not restricted based on gestationa...
# 38  Abortion is banned at 24 weeks and later |Pati...
# 39  Abortion is banned at fetal viability, general...
# 40  Abortion is banned at 6 weeks and later |Patie...
# 41  Abortion is completely banned with very limite...
# 42  Abortion is banned at 6 weeks and later | “Tri...
# 43  Abortion is banned at 6 weeks and later | Pre-...
# 44  “Trigger” ban on abortion is designed to take ...
# 45  Abortion is not restricted based on gestationa...
# 46  Abortion is banned starting at the third trime...
# 47  Abortion is banned at fetal viability, general...
# 48  Pre-Roe abortion ban is still in place and can...
# 49  Pre-Roe abortion ban is still in place and can...
# 50  “Trigger” ban on abortion is designed to take ...
#
#     Abortions Obtained in 2020  Abortions per 1,000 WORA in 2020  \
# 0                         5700                               6.0
# 1                         1240                               8.6
# 2                        13320                               9.3
# 3                         3250                               5.6
# 4                       154060                              19.2
# 5                        13420                              11.2
# 6                        11170                              16.7
# 7                         9410                              48.9
# 8                         1830                              10.0
# 9                        77400                              19.7
# 10                       41620                              18.9
# 11                        3130                              12.1
# 12                        1690                               4.8
# 13                       52780                              21.3
# 14                        7880                               6.0
# 15                        3510                               5.9
# 16                        8190                              14.5
# 17                        4080                               4.8
# 18                        7360                               8.0
# 19                        2370                              10.1
# 20                       30750                              25.9
# 21                       17060                              12.2
# 22                       31510                              16.8
# 23                       11060                              10.2
# 24                        3560                               6.1
# 25                         170                               0.1
# 26                        1630                               8.2
# 27                        2200                               5.9
# 28                       11010                              17.9
# 29                        2050                               8.3
# 30                       48830                              29.2
# 31                        5880                              14.7
# 32                      110360                              28.8
# 33                       31850                              15.3
# 34                        1170                               7.8
# 35                       20990                               9.5
# 36                        9690                              12.4
# 37                        8560                              10.3
# 38                       32270                              13.6
# 39                        2760                              13.3
# 40                        5300                               5.3
# 41                         130                               0.8
# 42                       10850                               8.1
# 43                       58030                               9.5
# 44                        3120                               4.4
# 45                        1230                              10.7
# 46                       18740                              11.0
# 47                       17980                              11.7
# 48                         990                               3.1
# 49                        6960                               6.4
# 50                         100                               0.9
#
#     Appx. Number of WORA  Abortion Clinics  Counties w/o Abortion Providers  \
# 0              1100000.0                 5                               93
# 1               161000.0                 4                               86
# 2              1600000.0                 8                               80
# 3               674000.0                 3                               97
# 4              9200000.0               161                               40
# 5              1400000.0                18                               80
# 6               780000.0                26                               13
# 7               212000.0                 4                                0
# 8               207000.0                 4                               33
# 9              4600000.0                65                               73
# 10             2600000.0                15                               95
# 11              301000.0                 4                               40
# 12              405000.0                 3                               95
# 13             2900000.0                25                               90
# 14             1500000.0                 6                               96
# 15              694000.0                 8                               93
# 16              644000.0                 4                               98
# 17              997000.0                 1                               99
# 18              100000.0                 4                               94
# 19              270000.0                16                               31
# 20             1400000.0                25                               71
# 21             1600000.0                19                               43
# 22             2200000.0                21                               87
# 23             1200000.0                 7                               97
# 24              677000.0                 1                               99
# 25             1400000.0                 3                               97
# 26              225000.0                 5                               93
# 27              422000.0                 3                               97
# 28              720000.0                 7                               88
# 29              289000.0                 4                               60
# 30              200000.0                41                               33
# 31              466000.0                 6                               91
# 32             4400000.0               113                               39
# 33             2400000.0                14                               91
# 34              168000.0                 1                               98
# 35             2600000.0                 9                               93
# 36              903000.0                 4                               96
# 37              961000.0                16                               78
# 38             2800000.0                18                               85
# 39              242000.0                 2                               60
# 40             1200000.0                 4                               93
# 41              190000.0                 1                               98
# 42             1600000.0                 8                               96
# 43              700000.0                21                               96
# 44              812000.0                 3                               97
# 45              131000.0                 6                               64
# 46              200000.0                16                               93
# 47             1800000.0                40                               59
# 48              367000.0                 1                               98
# 49             1300000.0                 3                               97
# 50              120000.0                 2                               96
#
#     % WORA w/o County Abortion Provider  ...  % WORA: 25-29 Years  \
# 0                                    59  ...                 15.0
# 1                                    32  ...                 18.0
# 2                                    18  ...                 15.0
# 3                                    77  ...                 15.0
# 4                                     3  ...                 16.0
# 5                                    27  ...                 16.0
# 6                                     5  ...                 13.0
# 7                                     0  ...                 23.0
# 8                                    18  ...                 15.0
# 9                                    24  ...                 15.0
# 10                                   55  ...                 14.0
# 11                                    5  ...                 15.0
# 12                                   67  ...                 15.0
# 13                                   37  ...                 15.0
# 14                                   70  ...                 14.0
# 15                                   58  ...                 15.0
# 16                                   61  ...                 15.0
# 17                                   82  ...                 14.0
# 18                                   72  ...                 16.0
# 19                                   24  ...                 13.0
# 20                                   29  ...                 14.0
# 21                                   13  ...                 15.0
# 22                                   35  ...                 15.0
# 23                                   61  ...                 15.0
# 24                                   91  ...                 15.0
# 25                                   78  ...                 15.0
# 26                                   56  ...                 14.0
# 27                                   40  ...                 16.0
# 28                                    9  ...                 16.0
# 29                                   30  ...                 13.0
# 30                                   26  ...                 14.0
# 31                                   48  ...                 15.0
# 32                                    8  ...                 16.0
# 33                                   53  ...                 15.0
# 34                                   72  ...                 14.0
# 35                                   55  ...                 15.0
# 36                                   53  ...                 15.0
# 37                                   23  ...                 15.0
# 38                                   48  ...                 15.0
# 39                                   22  ...                 15.0
# 40                                   71  ...                 15.0
# 41                                   76  ...                 13.0
# 42                                   63  ...                 16.0
# 43                                   43  ...                 15.0
# 44                                   63  ...                 15.0
# 45                                   38  ...                 12.0
# 46                                   80  ...                 14.0
# 47                                   10  ...                 16.0
# 48                                   90  ...                 14.0
# 49                                   70  ...                 14.0
# 50                                   96  ...                 11.0
#
#     % WORA: 30-39 Years  % WORA: 40-49 Years  Avg. Distance (mi): 6 Weeks  \
# 0                  29.0                 28.0                          NaN
# 1                  33.0                 26.0                          NaN
# 2                  28.0                 27.0                          NaN
# 3                  29.0                 28.0                          NaN
# 4                  30.0                 27.0                          NaN
# 5                  32.0                 26.0                          NaN
# 6                  28.0                 29.0                          NaN
# 7                  35.0                 18.0                          NaN
# 8                  30.0                 27.0                          NaN
# 9                  30.0                 29.0                          NaN
# 10                 29.0                 28.0                          NaN
# 11                 31.0                 29.0                         13.0
# 12                 29.0                 26.0                          NaN
# 13                 29.0                 28.0                          NaN
# 14                 29.0                 27.0                          NaN
# 15                 29.0                 26.0                          NaN
# 16                 27.0                 27.0                          NaN
# 17                 28.0                 29.0                         99.0
# 18                 31.0                 26.0                          NaN
# 19                 29.0                 31.0                          NaN
# 20                 31.0                 29.0                          NaN
# 21                 29.0                 26.0                          NaN
# 22                 29.0                 26.0                          NaN
# 23                 30.0                 27.0                          NaN
# 24                 29.0                 28.0                          NaN
# 25                 30.0                 27.0                          NaN
# 26                 29.0                 28.0                          NaN
# 27                 29.0                 25.0                          NaN
# 28                 29.0                 29.0                          NaN
# 29                 30.0                 28.0                          NaN
# 30                 29.0                 29.0                          NaN
# 31                 30.0                 26.0                          NaN
# 32                 31.0                 27.0                          NaN
# 33                 28.0                 29.0                          NaN
# 34                 29.0                 25.0                          NaN
# 35                 29.0                 28.0                         19.0
# 36                 29.0                 27.0                          NaN
# 37                 30.0                 29.0                          NaN
# 38                 30.0                 27.0                          NaN
# 39                 28.0                 27.0                          NaN
# 40                 29.0                 28.0                         23.0
# 41                 29.0                 26.0                          NaN
# 42                 29.0                 28.0                          NaN
# 43                 30.0                 27.0                          NaN
# 44                 27.0                 25.0                          NaN
# 45                 30.0                 26.0                          NaN
# 46                 30.0                 28.0                          NaN
# 47                 32.0                 27.0                          NaN
# 48                 27.0                 31.0                          NaN
# 49                 30.0                 27.0                          NaN
# 50                 35.0                 25.0                          NaN
#
#     Avg. Distance (mi): 12 Weeks  Avg. Distance (mi): 14 Weeks  \
# 0                          115.0                         118.0
# 1                            9.0                          11.0
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            4.0                           8.0
# 5                            9.0                           NaN
# 6                            6.0                           NaN
# 7                            NaN                           NaN
# 8                            NaN                           NaN
# 9                            8.0                          10.0
# 10                          17.0                          24.0
# 11                           NaN                           NaN
# 12                          21.0                           NaN
# 13                           7.0                           NaN
# 14                          23.0                          43.0
# 15                          33.0                           NaN
# 16                          30.0                           NaN
# 17                           NaN                         118.0
# 18                           NaN                          37.0
# 19                          12.0                          25.0
# 20                           6.0                           NaN
# 21                           8.0                           NaN
# 22                          11.0                           NaN
# 23                          16.0                          17.0
# 24                           NaN                          80.0
# 25                           NaN                           NaN
# 26                          22.0                          49.0
# 27                           NaN                           NaN
# 28                           7.0                           8.0
# 29                          12.0                           NaN
# 30                           5.0                           6.0
# 31                          24.0                           NaN
# 32                           3.0                           4.0
# 33                           NaN                          18.0
# 34                           NaN                           NaN
# 35                           NaN                         120.0
# 36                           NaN                           NaN
# 37                           7.0                          11.0
# 38                          11.0                          14.0
# 39                           7.0                           NaN
# 40                           NaN                          74.0
# 41                         190.0                           NaN
# 42                          26.0                          27.0
# 43                           NaN                           NaN
# 44                           NaN                           NaN
# 45                          16.0                          38.0
# 46                           NaN                           NaN
# 47                           6.0                          10.0
# 48                           NaN                          64.0
# 49                          34.0                           NaN
# 50                         132.0                           NaN
#
#     Avg. Distance (mi): 20 Weeks  Avg. Distance (mi): 22 Weeks  \
# 0                          137.0                         179.0
# 1                            NaN                           NaN
# 2                           11.0                           NaN
# 3                          160.0                         328.0
# 4                            9.0                          12.0
# 5                           11.0                          20.0
# 6                           15.0                           NaN
# 7                            7.0                           NaN
# 8                            2.0                           NaN
# 9                           12.0                          16.0
# 10                          29.0                          38.0
# 11                          14.0                           NaN
# 12                          36.0                         286.0
# 13                          10.0                           NaN
# 14                         155.0                           NaN
# 15                          47.0                         170.0
# 16                           NaN                          31.0
# 17                         158.0                         268.0
# 18                          71.0                         525.0
# 19                          32.0                           NaN
# 20                           7.0                           NaN
# 21                           9.0                          13.0
# 22                          13.0                           NaN
# 23                          18.0                           NaN
# 24                          90.0                         378.0
# 25                           NaN                          44.0
# 26                          77.0                         232.0
# 27                          10.0                          51.0
# 28                           9.0                           NaN
# 29                          17.0                          58.0
# 30                           8.0                           NaN
# 31                          37.0                           NaN
# 32                           5.0                           8.0
# 33                          26.0                          27.0
# 34                         165.0                         326.0
# 35                         149.0                           NaN
# 36                         180.0                         181.0
# 37                          29.0                          35.0
# 38                          20.0                          28.0
# 39                           8.0                          18.0
# 40                         102.0                         107.0
# 41                         191.0                         220.0
# 42                          29.0                         236.0
# 43                         250.0                         547.0
# 44                          30.0                          33.0
# 45                          40.0                          97.0
# 46                          14.0                          27.0
# 47                          14.0                          20.0
# 48                          65.0                         126.0
# 49                          37.0                          77.0
# 50                         169.0                         181.0
#
#     Avg. Distance (mi): 24 Weeks  Avg. Distance (mi): 24+ Weeks
# 0                          474.0                          507.0
# 1                            NaN                            NaN
# 2                           22.0                           25.0
# 3                            NaN                          360.0
# 4                            NaN                           14.0
# 5                           22.0                          851.0
# 6                           17.0                           64.0
# 7                           15.0                           50.0
# 8                            NaN                            3.0
# 9                           22.0                          910.0
# 10                         450.0                          558.0
# 11                          19.0                            0.0
# 12                           NaN                          428.0
# 13                          26.0                          266.0
# 14                         174.0                          235.0
# 15                         229.0                          252.0
# 16                         330.0                          355.0
# 17                           NaN                          274.0
# 18                         638.0                          673.0
# 19                         147.0                          321.0
# 20                          15.0                           29.0
# 21                          23.0                          180.0
# 22                          19.0                           26.0
# 23                          21.0                           25.0
# 24                           NaN                          499.0
# 25                           NaN                          155.0
# 26                         569.0                          667.0
# 27                         377.0                          397.0
# 28                          11.0                          238.0
# 29                          59.0                          215.0
# 30                          13.0                           16.0
# 31                          64.0                          423.0
# 32                           9.0                           10.0
# 33                           NaN                          335.0
# 34                         399.0                          402.0
# 35                         157.0                          195.0
# 36                         500.0                          512.0
# 37                           NaN                           36.0
# 38                          29.0                           84.0
# 39                          46.0                          149.0
# 40                         427.0                          492.0
# 41                         277.0                          290.0
# 42                           NaN                          320.0
# 43                         705.0                          786.0
# 44                         416.0                          652.0
# 45                         201.0                          285.0
# 46                           NaN                          113.0
# 47                           NaN                           21.0
# 48                         167.0                          283.0
# 49                         125.0                          242.0
# 50                         331.0                          829.0
#
# [51 rows x 30 columns]

# %%
ages_6.to_csv("WORA_ages_unpivoted.csv")
wora_ethnicities6.to_csv("WORA_ethnicity_unpivoted.csv")
driving_distance3.to_csv("Avg_Drive_Distance.csv")
abortion_data_cleaned.to_csv("Guttmacher_Webscrape.csv")
